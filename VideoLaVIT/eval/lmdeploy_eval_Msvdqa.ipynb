# %%
import os
import gc
import re
import sys
import csv
import time
import tqdm
import json
import numpy as np
import pandas as pd
from copy import deepcopy
from pathlib import Path
from pprint import pprint
from typing import Optional, Any, List, Union, Tuple, Dict, Callable
from collections import defaultdict, OrderedDict, Counter

import openai
import asyncio
from tqdm.asyncio import tqdm_asyncio

# %% [markdown]
# 1) Install https://github.com/InternLM/lmdeploy/tree/main
# 2) run: lmdeploy serve api_server Qwen/Qwen2.5-14B-Instruct  --server-port 23333

# %%
from openai import OpenAI, AsyncOpenAI

client = AsyncOpenAI(api_key='YOUR_API_KEY', base_url='http://0.0.0.0:23333/v1')

# %%
model_names = await client.models.list()
MODEL_NAME = model_names.data[0].id
MODEL_NAME
# Out:
# 'unsloth/llama-3-8b-Instruct'

# %%
question = "Who pours liquid from a plastic container into a ziploc bag containing meat pieces?"
answer = "Man"
pred = "Someone"

# %%
messages=[
        {
            "role": "system",
            "content": 
                "You are an intelligent chatbot designed for evaluating the correctness of generative outputs for question-answer pairs. "
                "Your task is to compare the predicted answer with the correct answer and determine if they match meaningfully. Here's how you can accomplish the task:"
                "------"
                "##INSTRUCTIONS: "
                "- Focus on the meaningful match between the predicted answer and the correct answer.\n"
                "- Consider synonyms or paraphrases as valid matches.\n"
                "- Evaluate the correctness of the prediction compared to the answer."
        },
        {
            "role": "user",
            "content":
                "Please evaluate the following video-based question-answer pair:\n\n"
                f"Question: {question}\n"
                f"Correct Answer: {answer}\n"
                f"Predicted Answer: {pred}\n\n"
                "Provide your evaluation only as a yes/no and score, where the evaluation is 'yes' if the Predicted Answer and Correct Answer have the same meaning in the context of the Question, 'no' in other cases; the score is an integer value between 0 and 5, with 5 indicating the highest meaningful match. "
                "Please generate the response in the form of a Python dictionary string with keys 'pred' and 'score', where value of 'pred' is  a string of 'yes' or 'no' and value of 'score' is in INTEGER, not STRING."
                "DO NOT PROVIDE ANY OTHER OUTPUT TEXT OR EXPLANATION. Only provide the Python dictionary string. "
                "For example, your response should look like this: {'pred': 'yes', 'score': 4.8}."
        }
    ]
pprint(messages)
# Out:
# [{'content': 'You are an intelligent chatbot designed for evaluating the '
#              'correctness of generative outputs for question-answer pairs. '
#              'Your task is to compare the predicted answer with the correct '
#              "answer and determine if they match meaningfully. Here's how you "
#              'can accomplish the task:------##INSTRUCTIONS: - Focus on the '
#              'meaningful match between the predicted answer and the correct '
#              'answer.\n'
#              '- Consider synonyms or paraphrases as valid matches.\n'
#              '- Evaluate the correctness of the prediction compared to the '
#              'answer.',
#   'role': 'system'},
#  {'content': 'Please evaluate the following video-based question-answer pair:\n'
#              '\n'
#              'Question: Who pours liquid from a plastic container into a '
#              'ziploc bag containing meat pieces?\n'
#              'Correct Answer: Man\n'
#              'Predicted Answer: Someone\n'
#              '\n'
#              'Provide your evaluation only as a yes/no and score, where the '
#              "evaluation is 'yes' if the Predicted Answer and Correct Answer "
#              "have the same meaning in the context of the Question, 'no' in "
#              'other cases; the score is an integer value between 0 and 5, with '
#              '5 indicating the highest meaningful match. Please generate the '
#              'response in the form of a Python dictionary string with keys '
#              "'pred' and 'score', where value of 'pred' is  a string of 'yes' "
#              "or 'no' and value of 'score' is in INTEGER, not STRING.DO NOT "
#              'PROVIDE ANY OTHER OUTPUT TEXT OR EXPLANATION. Only provide the '
#              'Python dictionary string. For example, your response should look '
#              "like this: {'pred': 'yes', 'score': 4.8}.",
#   'role': 'user'}]

# %%
response = await client.chat.completions.create(
    model=MODEL_NAME,
    messages=messages,
    temperature=0.0,
    max_completion_tokens=250,
    # extra_body={"guided_json": answer_schema, "guided_decoding_backend": "outlines"},
)
print(response)
# Out:
# ChatCompletion(id='1', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="{'pred': 'yes', 'score': 5}", refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1738947859, model='unsloth/llama-3-8b-Instruct', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=12, prompt_tokens=306, total_tokens=318, completion_tokens_details=None, prompt_tokens_details=None))

# %%
import json
file = open("sample_set.json")
pred_contents = json.load(file)

# %%
import ast

answers = []
scores = []
for ind, elem in enumerate(pred_contents):
    question = elem['q'][0].split('?')[0] + '?'
    answer = elem['real']
    pred = elem['a']
    
    completion = await client.chat.completions.create(
                    model=MODEL_NAME,
                    messages=[
                        {
                            "role": "system",
                            "content": 
                                "You are an intelligent chatbot designed for evaluating the correctness of generative outputs for question-answer pairs. "
                                "Your task is to compare the predicted answer with the correct answer and determine if they match meaningfully. Here's how you can accomplish the task:"
                                "------"
                                "##INSTRUCTIONS: "
                                "- Focus on the meaningful match between the predicted answer and the correct answer.\n"
                                "- Consider synonyms or paraphrases as valid matches.\n"
                                "- Evaluate the correctness of the prediction compared to the answer."
                        },
                        {
                            "role": "user",
                            "content":
                                "Please evaluate the following video-based question-answer pair:\n\n"
                                f"Question: {question}\n"
                                f"Correct Answer: {answer}\n"
                                f"Predicted Answer: {pred}\n\n"
                                "Provide your evaluation only as a yes/no and score, where the evaluation is 'yes' if the Predicted Answer and Correct Answer have the same meaning in the context of the Question, 'no' in other cases; the score is an integer value between 0 and 5, with 5 indicating the highest meaningful match. "
                                "Please generate the response in the form of a Python dictionary string with keys 'pred' and 'score', where value of 'pred' is a string of 'yes' or 'no' and value of 'score' is in INTEGER, not STRING."
                                "DO NOT PROVIDE ANY OTHER OUTPUT TEXT OR EXPLANATION. Only provide the Python dictionary string. "
                                "For example, your response should look like this: {'pred': 'yes', 'score': 4.8}."
                        }
                    ]
    )
    # Convert response to a Python dictionary.
    if (ind%100 ==0):
        print (ind)
        print (print (question, answer, pred))
        print (ast.literal_eval(completion.choices[0].message.content)['pred'])
        print (ast.literal_eval(completion.choices[0].message.content)['score'])
    try:
        answers.append(ast.literal_eval(completion.choices[0].message.content)['pred'])
        scores.append(ast.literal_eval(completion.choices[0].message.content)['score'])
    except:
        answers.append(ast.literal_eval(completion.choices[0].message.content.split("\n\nExplanation")[0])['pred'])
        scores.append(ast.literal_eval(completion.choices[0].message.content.split("\n\nExplanation")[0])['score'])
# Out:
# 0
# Who pours liquid from a plastic container into a ziploc bag containing meat pieces? Someone Man
# None
# yes
# 5
# 100
# Who caught a ball? Man Catcher
# None
# yes
# 5
# 200
# Who is hanging on a vine? Woman Cat
# None
# no
# 0
# 300
# What does a man operate remote control car through? Office Window
# None
# no
# 1
# 400
# What is a young boy playing? Piano Piano
# None
# yes
# 5
# 500
# What is a man doing? Sand A man is being painted near a statue which is being worked on and another man is pointing and laughing.
# None
# no
# 0
# 600
# Who is carrying another man on his back? Man Person in black robe
# None
# no
# 0
# 700
# What is a man doing? Play Playing guitar
# None
# yes
# 5
# 800
# Who poured oil on the tomato slices? Man Man
# None
# yes
# 5
# 900
# Who pops a wheely in the street? Driver Biker
# None
# yes
# 4
# 1000
# Who petting a beaver? Someone Hand
# None
# yes
# 4
# 1100
# What is a flight attendant closing the emergency door of? Plane Plane
# None
# yes
# 5
# 1200
# What is eating nuts on the floor? Hamster Hamster
# None
# yes
# 5
# 1300
# What is playing paino? Someone Hands of a person
# None
# yes
# 5
# 1400
# What is walking on snow? Fox Fox
# None
# yes
# 5
# 1500
# What is the boy playing? Flute Flute
# None
# yes
# 5
# 1600
# Who waits for a man walking down the street behind a tree? Woman Girl
# None
# yes
# 4
# 1700
# What is a person pushing a man off? Boat Ship
# None
# yes
# 5
# 1800
# What is a man slicing? Tomato Tomato
# None
# yes
# 5
# 1900
# What is a person creating a folder on? Computer Computer
# None
# yes
# 5
# 2000
# What is a boy adding juice in? Cup Bean bag
# None
# no
# 0
# 2100
# What is a man stirring in a bowl? Mixture Flour
# None
# no
# 0
# 2200
# Who is pouring coffee into a cup? Person Woman
# None
# yes
# 5
# 2300
# Who hammers a knife into a wooden board? Man Person
# None
# yes
# 5
# 2400
# What is a woman playing with? Rabbit Rabbit
# None
# yes
# 5
# 2500
# What is playing a piano? Someone Candles
# None
# no
# 1
# 2600
# Who is riding a motorcycle in the water at the edge of a beach? Man Man
# None
# yes
# 5
# 2700
# What is a kitten doing? Fail Sitting
# None
# no
# 0
# 2800
# Who dries off a woman? Man Man
# None
# yes
# 5
# 2900
# Who rakes leaves? Woman Guy
# None
# yes
# 4
# 3000
# Who is performing aerobics? Woman Woman
# None
# yes
# 5
# 3100
# Who is standing? Man Woman
# None
# no
# 0
# 3200
# What does a dog come close to? Duck Duckling
# None
# yes
# 5
# 3300
# What is someone squeezing a handful of some white substance into? Lump Bowl
# None
# no
# 0
# 3400
# What are two men playing? Tenni Table tennis
# None
# yes
# 5
# 3500
# What is a man doing? Extract The man is seen standing behind a counter and talking to the camera. Later on, he is shown sitting at a table with a cup of liquid next to him.
# None
# yes
# 4
# 3600
# What are a bunch of ants doing? Gather Eating
# None
# no
# 1
# 3700
# Who picks up a slice of pizza? Man Man
# None
# yes
# 5
# 3800
# What is driven? Car Car
# None
# yes
# 5
# 3900
# What is a woman poking with a fork? Potato Meat
# None
# no
# 0
# 4000
# How many young men are standing on stage playing guitars? Three 3
# None
# yes
# 5
# 4100
# What is someone drifting in? Car Fire
# None
# no
# 0
# 4200
# What is a man doing? Operate Cooking
# None
# no
# 0
# 4300
# What are a large group of men and women doing? Dance Dancing
# None
# yes
# 5
# 4400
# What is a woman in a teacup being bombarded with by a bigger man? Sugar Cup of tea
# None
# no
# 0
# 4500
# What does a person pour cooking into a pot? Oil Olive oil
# None
# yes
# 5
# 4600
# Who is pouring tomato sauce from a can into a saucepan containing meat pieces? Someone Man
# None
# yes
# 5
# 4700
# What does a man put on a plate of spaghetti? Tomato Sauce
# None
# yes
# 4
# 4800
# Who is being pulling into a lake? Woman Girl
# None
# yes
# 5
# 4900
# What is showing fight stunts? Monkey Kids hitting
# None
# no
# 0
# 5000
# What is getting a bath? Hedgehog Hedgehog
# None
# yes
# 5
# 5100
# What is a man playing? Keyboard Piano
# None
# yes
# 5
# 5200
# Who is playing guitar? Man Man
# None
# yes
# 5
# 5300
# What are two men playing? Tenni Tennis
# None
# yes
# 5
# 5400
# What was one man fought with another man who doing? Try It's unclear
# None
# yes
# 5
# 5500
# What is the baby putting the dishes in? Container Dishwasher
# None
# no
# 1
# 5600
# What is a woman doing? Pet Texting
# None
# no
# 0
# 5700
# Who is making pancakes on a stove? Man Man
# None
# yes
# 5
# 5800
# Who is spinning? Woman Woman
# None
# yes
# 5
# 5900
# What is a person doing? Slouse In the video, a person is slicing a bread on the wooden table. One end of the knife is held at an angle to the table, and the other end is shown gliding through the bread, slicing it neatly in half.
# None
# yes
# 5
# 6000
# What is going down a slide? Panda Snow
# None
# no
# 0
# 6100
# What is a chef rolling? Dough Dough
# None
# yes
# 5
# 6200
# Who is cutting meat with axe? Man Guy
# None
# yes
# 5
# 6300
# What did the pet store worker put into the box? Lizard Mouse
# None
# no
# 0

# %%
import numpy as np
np.mean(scores)
# Out:
# 3.19953125

# %%
import pickle
file = open("gpt_answers.pkl",'rb')
answers_gpt = pickle.load(file)

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(answers, answers_gpt[:len(answers)])
# Out:
# 0.37033607494961596

# %%
score_sum = 0
count = 0
yes_count = 0
no_count = 0
for pred in answers:
    if "yes" in pred.lower():
        yes_count += 1
    elif "no" in pred.lower():
        no_count += 1


accuracy = yes_count / (yes_count + no_count)
accuracy
# Out:
# 0.63359375
